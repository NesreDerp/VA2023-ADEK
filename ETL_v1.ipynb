# %% [markdown]
# # Exam

# %% [markdown]
# ### Creating one coherent data set (from four similar data sets)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# #### Importing data

# %%
# Data set 0 (2015)
dfIndiaSUF0 = pd.DataFrame() # Create an empyty dataframe of Indian Start-Up Funding Data
monthList0 = ["Jan", "Feb", "Mar", ] # List of months in data
yearList0 = ["2015"] # List of years in data
 
for y, m in [(y,m) for y in yearList0 for m in monthList0]: # Loops through each element in yearList, and for each element it loops through each element of monthList
    try: # Tests if code can run e.g. checks if the file or is data in the file exists
        dfNewTemp0 = pd.read_csv('Indian Start-Up Funding Data/'+m+'_'+y+'.csv', skipinitialspace = True) # Creates a temporary dataframe for read/imported data from data file
        dfIndiaSUF0 = dfIndiaSUF0.append(dfNewTemp0) # Adds above dataframe below existing data in the main dataframe
    except: # If above error returns an error
        continue # Skips the above code and import of filedata

# %%
## Data set 01 (2015)
dfIndiaSUF0_1 = pd.DataFrame() # Create an empyty dataframe of Indian Start-Up Funding Data
monthList0_1 = ["Apr", "May", "Jun", "Jul", "Aug", "Sep", "Okt", "Nov", "Dec"] # List of months in data
yearList0_1 = ["2015"] # List of years in data
 
for y, m in [(y,m) for y in yearList0_1 for m in monthList0_1]: # Loops through each element in yearList, and for each element it loops through each element of monthList
    try: # Tests if code can run e.g. checks if the file or is data in the file exists
        dfNewTemp0_1 = pd.read_csv('Indian Start-Up Funding Data/'+m+'_'+y+'.csv', skipinitialspace = True) # Creates a temporary dataframe for read/imported data from data file
        dfIndiaSUF0_1 = dfIndiaSUF0_1.append(dfNewTemp0_1) # Adds above dataframe below existing data in the main dataframe
    except: # If above error returns an error
        continue # Skips the above code and import of filedata

# %%
# Data set 1 (2016-2019)
dfIndiaSUF1 = pd.DataFrame() # Create an empyty dataframe of Indian Start-Up Funding Data
monthList1 = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Okt", "Nov", "Dec"] # List of months in data
yearList1 = ["2016", "2017", "2018", "2019"] # List of years in data
 
for y, m in [(y,m) for y in yearList1 for m in monthList1]: # Loops through each element in yearList, and for each element it loops through each element of monthList
    try: # Tests if code can run e.g. checks if the file or is data in the file exists
        dfNewTemp1 = pd.read_csv('Indian Start-Up Funding Data/'+m+'_'+y+'.csv', skipinitialspace = True) # Creates a temporary dataframe for read/imported data from data file
        dfIndiaSUF1 = dfIndiaSUF1.append(dfNewTemp1) # Adds above dataframe below existing data in the main dataframe
    except: # If above error returns an error
        continue # Skips the above code and import of filedata

# %%
# Data set 2 (2020-2021)
dfIndiaSUF2 = pd.DataFrame() # Create an empyty dataframe of Indian Start-Up Funding Data
monthList2 = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Okt", "Nov", "Dec"] # List of months in data
yearList2 = ["2020", "2021"] # List of years in data
   
for y, m in [(y,m) for y in yearList2 for m in monthList2]: # Loops through each element in yearList, and for each element it loops through each element of monthList
    try: # Tests if code can run e.g. checks if the file or is data in the file exists
        dfNewTemp2 = pd.read_csv('Indian Start-Up Funding Data/'+m+'_'+y+'.csv', skipinitialspace = True, sep=';') # Creates a temporary dataframe for read/imported data from data file
        dfIndiaSUF2 = dfIndiaSUF2.append(dfNewTemp2) # Adds above dataframe below existing data in the main dataframe
    except: # If above error returns an error
        continue # Skips the above code and import of filedata

# %%
# Data preview 1/4
dfIndiaSUF0.head(2)
# Out:
#    Sr. No.        Date  Startup Name  \
# 0      1.0  02/01/2015      LensKart
# 1      2.0  02/01/2015  VioletStreet
#
#                                        Investor Name Investment Type  \
# 0               TPG Growth, TR Capital, IDG Ventures  Private Equity
# 1  Venkat Vallabhneni, Sudhakar Reddy, Srinivasa ...     SeedFunding
#
#   Amount(in USD) Remarks
# 0      2,150,000     NaN
# 1        315,000     NaN

# %%
# Data preview 2/4
dfIndiaSUF0_1.head(2)
# Out:
#    Sr. No.        Date Startup Name       Industry/Vertical       City  \
# 0      1.0  03/04/2015       Swiggy    Online Food Delivery  Bangalore
# 1      2.0  04/04/2015     Bluegape  Web Content Publishing    Gurgaon
#
#                        Investor Name  InvestmentType Amount(in USD)   Remarks
# 0      Accel Partners, SAIF Partners  Private Equity      2,000,000  Series A
# 1  Rudy Gopalakrishnan, ah! Ventures    Seed Funding        200,000       NaN

# %%
# Data preview 2/4
dfIndiaSUF1.head(2)
# Out:
#    Sr. No.       Date Startup Name  Industry/Vertical  \
# 0      1.0  01/1/2016   Smartcooky          ECommerce
# 1      2.0  01/1/2016        Helpi  Consumer Internet
#
#                               Sub-Vertical       City  \
# 0  Health Food / Personal Care Marketplace  New Delhi
# 1   On Demand Cleaning Services Mobile App     Mumbai
#
#                                        Investor Name Investment Type  \
# 0  Rajan Anandan, Pramod Bhasin, Siddharth Pai, T...    Seed Funding
# 1                              Undisclosed Investors    Seed Funding
#
#   Amount(in USD)
# 0            NaN
# 1            NaN

# %%
# Data preview 3/4
dfIndiaSUF2.head(2)
# Out:
#    Unnamed: 0 Startup Name Funding Date Founding Date       City  \
# 0           0       AdonMo   01/01/2020        2017.0  Bangalore
# 1           1    RACEnergy   01/01/2020        2018.0        NaN
#
#   Industry/Vertical                                       Sub-Vertical  \
# 0           Ad-tech    It is an online and outdoor advertising company
# 1        E-mobility  It builds electric vehicles and supporting inf...
#
#                               Founders                           Investors  \
# 0  Sandeep Bommireddi, Sravanth Gajula                       Ant Financial
# 1      Arun Sreyas, Gautham Maheswaran  GrowX ventures, Prophetic Ventures
#
#   Amount(in USD) Investment Stage
# 0     $3,000,000              NaN
# 1    Undisclosed       Seed Round

# %% [markdown]
# #### Cleaning up data sets for joining

# %%
# Renaming column
dfIndiaSUF0_1 = dfIndiaSUF0_1.rename(columns={"InvestmentType": "Investment Type"})

# %%
# Adding data set 0 to end of data set 01
dfIndiaSUF0 = dfIndiaSUF0_1.append(dfIndiaSUF0) # Adds above dataframe below existing data in the main dataframe

# %%
# Moving data column, by assigning it, deleting it, and then adding it again
dfIndiaSUF0_Remarks = dfIndiaSUF0.pop('Remarks')
dfIndiaSUF0.insert(8, 'Remarks', dfIndiaSUF0_Remarks)

# Adding column, with NaN calues, to match data sets
dfIndiaSUF0.insert(4, 'Sub-Vertical', np.nan)

# %%
# Moving data column, by assigning it, deleting it, and then adding it again
dfIndiaSUF0_InvestmentType = dfIndiaSUF0.pop('Investment Type')
dfIndiaSUF0.insert(8, 'Investment Type', dfIndiaSUF0_InvestmentType)
dfIndiaSUF0_City = dfIndiaSUF0.pop('City')
dfIndiaSUF0.insert(5, 'City', dfIndiaSUF0_City)

# Renaming (exchanging two) index columns
dfIndiaSUF0 = dfIndiaSUF0.rename(columns={"Investment Type": "Investment Type", "Amount(in USD)": "Amount(in USD)", "City": "City", "Sub-Vertical": "Sub-Vertical"})

# %%
# Adding data set 1 to end of data set 0
dfIndiaSUF1 = dfIndiaSUF0.append(dfIndiaSUF1)

# %%
# Deleting first index column in both data sets
dfIndiaSUF1 = dfIndiaSUF1.iloc[: , 1:]
dfIndiaSUF2 = dfIndiaSUF2.iloc[: , 1:]

# Moving data column, by assigning it, deleting it, and then adding it again
dfIndiaSUF1_StartupName = dfIndiaSUF1.pop('Startup Name')
dfIndiaSUF1.insert(0, 'Startup Name', dfIndiaSUF1_StartupName)

# Moving data column, by assigning it, deleting it, and then adding it again
dfIndiaSUF2_Founders = dfIndiaSUF2.pop('Founders')
dfIndiaSUF2.insert(1, 'Founders', dfIndiaSUF2_Founders)
dfIndiaSUF2_InvestmentStage = dfIndiaSUF2.pop("Investment Stage")
dfIndiaSUF2.insert(7, 'Investment Stage', dfIndiaSUF2_InvestmentStage)
dfIndiaSUF2_City = dfIndiaSUF2.pop('City')
dfIndiaSUF2.insert(5, 'City', dfIndiaSUF2_City)

# Adding column, with NaN calues, to match data sets
dfIndiaSUF1.insert(1, 'Founders', np.nan)
dfIndiaSUF2.insert(9, 'Remarks', np.nan)
dfIndiaSUF1.insert(3, 'Founding Date', np.nan)

# %%
# Renaming index columns, to match data sets
dfIndiaSUF1 = dfIndiaSUF1.rename(columns={'Startup Name': 'Startup Name', 'Founders': 'Founder(s)', 'Date': 'Funding Date', 'Industry/Vertical': 'Industry/Vertical', 'Sub-Vertical': 'Sub-Vertical', 'City': 'City', 'Investor Name': 'Investor(s)', 'Investment Type': 'Investment Type', 'Amount(in USD)': 'Investment Amount (USD)', 'Remarks': 'Remarks'})
dfIndiaSUF2 = dfIndiaSUF2.rename(columns={'Startup Name': 'Startup Name', 'Founders': 'Founder(s)', 'Founding Date': 'Founding Date', 'Industry/Vertical': 'Industry/Vertical', 'Sub-Vertical': 'Sub-Vertical', 'City': 'City', 'Investors': 'Investor(s)', 'Investment Stage': 'Investment Type', 'Amount(in USD)': 'Investment Amount (USD)', 'Remarks': 'Remarks'})

# %%
# Adding data set 2 to end of data set 1
dfIndiaSUF = dfIndiaSUF1.append(dfIndiaSUF2) # Adds above dataframe below existing data in the main dataframe

# %% [markdown]
# ### Summary Statistics

# %%
# Data preview
dfIndiaSUF.head(2)
# Out:
#   Startup Name Founder(s) Funding Date Founding Date       Industry/Vertical  \
# 0       Swiggy        NaN   03/04/2015           NaN    Online Food Delivery
# 1     Bluegape        NaN   04/04/2015           NaN  Web Content Publishing
#
#   Sub-Vertical       City                        Investor(s)  \
# 0          NaN  Bangalore      Accel Partners, SAIF Partners
# 1          NaN    Gurgaon  Rudy Gopalakrishnan, ah! Ventures
#
#   Investment Amount (USD) Investment Type   Remarks
# 0               2,000,000  Private Equity  Series A
# 1                 200,000    Seed Funding       NaN

# %%
# Size of the data set (rows, columns)
dfIndiaSUF.shape
# Out:
# (4831, 11)

# %%
# Column information
dfIndiaSUF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4831 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Startup Name             4779 non-null   object
#  1   Founder(s)               1938 non-null   object
#  2   Funding Date             4795 non-null   object
#  3   Founding Date            1771 non-null   object
#  4   Industry/Vertical        4596 non-null   object
#  5   Sub-Vertical             3936 non-null   object
#  6   City                     4524 non-null   object
#  7   Investor(s)              4667 non-null   object
#  8   Investment Amount (USD)  3881 non-null   object
#  9   Investment Type          3995 non-null   object
#  10  Remarks                  375 non-null    object
# dtypes: object(11)
# memory usage: 452.9+ KB

# %%
# Description of non string data
dfIndiaSUF.describe()
# Out:
#        Startup Name                        Founder(s) Funding Date  \
# count          4779                              1938         4795
# unique         3649                              1688          984
# top          Swiggy  Ashneer Grover, Shashvat Nakrani   01/09/2020
# freq             11                                 6          156
#
#         Founding Date  Industry/Vertical             Sub-Vertical       City  \
# count          1771.0               4596                     3936       4524
# unique           44.0               1134                     3655        163
# top            2019.0  Consumer Internet  Online Lending Platform  Bangalore
# freq            246.0                893                       11       1290
#
#                   Investor(s) Investment Amount (USD) Investment Type  \
# count                    4667                    3881            3995
# unique                   3637                     968              93
# ...

# %%
# Changing empty values to NaN
dfIndiaSUF = dfIndiaSUF.replace('',np.nan,regex = True)

# %%
# Sum of null values
dfIndiaSUF.isna().sum()
# Out:
# Startup Name                 52
# Founder(s)                 2893
# Funding Date                 36
# Founding Date              3060
# Industry/Vertical           235
# Sub-Vertical                895
# City                        307
# Investor(s)                 164
# Investment Amount (USD)     950
# Investment Type             836
# Remarks                    4456
# dtype: int64

# %% [markdown]
# ### Data Set Cleaning

# %% [markdown]
# #### 'Startup Name' column

# %%
# Title capitalisation
dfIndiaSUF['Startup Name'] = dfIndiaSUF['Startup Name'].str.title()

# %%
# Columns where 'Startup Name' has no value
dfIndiaSUF[dfIndiaSUF['Startup Name'].isnull()]
# Out:
#     Startup Name Founder(s) Funding Date Founding Date Industry/Vertical  \
# 58           NaN        NaN          NaN           NaN               NaN
# 59           NaN        NaN          NaN           NaN               NaN
# 86           NaN        NaN          NaN           NaN               NaN
# 98           NaN        NaN          NaN           NaN               NaN
# 99           NaN        NaN          NaN           NaN               NaN
# 100          NaN        NaN          NaN           NaN               NaN
# 98           NaN        NaN   31/08/2015           NaN               NaN
# 99           NaN        NaN   31/08/2015           NaN               NaN
# 88           NaN        NaN          NaN           NaN               NaN
# 89           NaN        NaN          NaN           NaN               NaN
# 90           NaN        NaN          NaN           NaN               NaN
# 92           NaN        NaN          NaN           NaN               NaN
# ...

# %%
# Deleting rows with no value in 'Start Up'
dfIndiaSUF = dfIndiaSUF[dfIndiaSUF['Startup Name'].notnull()]

# Test of above code
dfIndiaSUF[dfIndiaSUF['Startup Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Startup Name, Founder(s), Funding Date, Founding Date, Industry/Vertical, Sub-Vertical, City, Investor(s), Investment Amount (USD), Investment Type, Remarks]
# Index: []

# %% [markdown]
# #### 'Founder(s)' column

# %%
# Title capitalisation
dfIndiaSUF['Founder(s)'] = dfIndiaSUF['Founder(s)'].str.title()

# %% [markdown]
# #### 'Funding Data' & 'Funding Date' column

# %%
# Creating temp variable, based on column 'Funding Date' if length of string is greater than four, it it will take last the first five value of the column, else it will insert NaN
dfIndiaSUFTemp = np.where(dfIndiaSUF['Funding Date'].str.len() > 4, dfIndiaSUF['Funding Date'].str[:5], np.nan)


dfIndiaSUF.insert(3, 'Funding Day', dfIndiaSUFTemp)

# Deleting all values in column except the last four
dfIndiaSUF['Funding Date'] = np.where(dfIndiaSUF['Funding Date'].str.len() > 4, dfIndiaSUF['Funding Date'].str[-4:], dfIndiaSUF['Funding Date'])

# %%
#### Checking for incosistant data values
dfIndiaSUF[dfIndiaSUF['Funding Day'].str.len() == 4]
# Out:
# Empty DataFrame
# Columns: [Startup Name, Founder(s), Funding Date, Funding Day, Founding Date, Industry/Vertical, Sub-Vertical, City, Investor(s), Investment Amount (USD), Investment Type, Remarks]
# Index: []

# %%
# Creating temporary column with month data
dfIndiaSUF.insert(3, 'Funding Month', dfIndiaSUF['Funding Day'].str[-2:])

# %%
# Checking and replacing '/' with a zero to ensure data consistancy
dfIndiaSUF['Funding Month'] = dfIndiaSUF['Funding Month'].str.replace('/', '0')

# %%
# Only keeping first two data values in column
dfIndiaSUF['Funding Day'] = dfIndiaSUF['Funding Day'].str[:2]

# %%
# All null Year values
dfIndiaSUF['Funding Date'].isnull().value_counts()
# Out:
# False    4779
# Name: Funding Date, dtype: int64

# %%
# Deleting all rows with null values in year
dfIndiaSUF = dfIndiaSUF[dfIndiaSUF['Funding Date'].notnull()]

dfIndiaSUF = dfIndiaSUF.drop(21)

# %%
# Correctly year value
dfIndiaSUF.loc[dfIndiaSUF['Funding Date'] == '/015', 'Funding Date'] = '2015'

# %%
#Chaning 'Funding Date' to data type int
dfIndiaSUF['Funding Date'] = dfIndiaSUF['Funding Date'].astype(int)

# %%
dfIndiaSUF['Funding Date'].value_counts()
# Out:
# 2021    1077
# 2016     927
# 2020     854
# 2015     832
# 2017     623
# 2018     295
# 2019     108
# Name: Funding Date, dtype: int64

# %%
# All month values
dfIndiaSUF['Funding Month'].value_counts()
# Out:
# 09    467
# 08    458
# 06    452
# 07    416
# 11    414
# 12    397
# 04    386
# 01    381
# 02    361
# 03    303
# 05    277
# 30     84
# 50     78
# 90     72
# 70     66
# 10     42
# 20     26
# 40     15
# 60     11
# 80     10
# Name: Funding Month, dtype: int64

# %%
# All months greater than 12
dfIndiaSUF[dfIndiaSUF['Funding Month'] > "12"]
# Out:
#           Startup Name Founder(s)  Funding Date Funding Month Funding Day  \
# 34      News In Shorts        NaN          2015            70          09
# 35           Bluestone        NaN          2015            70          09
# 36            Shopsity        NaN          2015            70          09
# 37            Notesgen        NaN          2015            70          09
# 38  Infinity Assurance        NaN          2015            70          10
# ..                 ...        ...           ...           ...         ...
# 10             Eshakti        NaN          2017            20          7/
# 11            Inshorts        NaN          2017            20          8/
# 0               Fleetx        NaN          2019            20          1/
# 1              Zilingo        NaN          2019            20          8/
# 2         Dhruva Space        NaN          2019            20          3/
#
#    Founding Date                         Industry/Vertical  \
# ...

# %%
# Fixing incorrect values in 'Funding Month'

#### Note "10" is not fixed, as 10 could be a month
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '20', 'Funding Month'] = '02'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '30', 'Funding Month'] = '03'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '40', 'Funding Month'] = '04'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '50', 'Funding Month'] = '05'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '60', 'Funding Month'] = '06'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '70', 'Funding Month'] = '07'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '80', 'Funding Month'] = '08'
dfIndiaSUF.loc[dfIndiaSUF['Funding Month'] == '90', 'Funding Month'] = '09'

# %%
# All day values
dfIndiaSUF['Funding Day'].value_counts()
# Out:
# 01    2027
# 22     116
# 12     105
# 08     103
# 10     102
# 19     101
# 03      99
# 04      99
# 23      99
# 21      98
# 07      94
# 05      92
# 29      91
# 13      91
# 17      90
# 06      90
# 15      89
# 18      88
# 09      88
# 14      88
# 02      86
# 30      86
# 11      85
# 25      83
# 16      83
# 24      82
# 28      77
# 27      76
# 20      75
# 26      74
# 31      36
# 5/       5
# 7/       4
# 8/       4
# 2/       2
# 1/       2
# 6/       2
# 9/       2
# 4/       1
# 3/       1
# Name: Funding Day, dtype: int64

# %%
# All days greater than 31
dfIndiaSUF[dfIndiaSUF['Funding Day'] > "31"]
# Out:
#                  Startup Name Founder(s)  Funding Date Funding Month  \
# 1                       Dunzo        NaN          2017            02
# 2                Tata Housing        NaN          2017            02
# 3                  Handytrain        NaN          2017            02
# 4                      Mobycy        NaN          2017            02
# 5           Greenlight Planet        NaN          2017            02
# 6                    Fintobox        NaN          2017            02
# 7                      Mswipe        NaN          2017            02
# 8              The Label Life        NaN          2017            02
# 9            Cygnus Hospitals        NaN          2017            02
# 10                    Eshakti        NaN          2017            02
# 11                   Inshorts        NaN          2017            02
# 1                 Earlysalary        NaN          2018            02
# 2                        Wotu        NaN          2018            02
# ...

# %%
# Removes all non digit values from column
dfIndiaSUF['Funding Day'] = dfIndiaSUF['Funding Day'].str.replace(r'[^0-9]+', '')

# %%
# Add 0 infront of incorrect values in 'Funding Day'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '1', 'Funding Day'] = '01'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '2', 'Funding Day'] = '02'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '3', 'Funding Day'] = '03'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '4', 'Funding Day'] = '04'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '5', 'Funding Day'] = '05'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '6', 'Funding Day'] = '06'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '7', 'Funding Day'] = '07'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '8', 'Funding Day'] = '08'
dfIndiaSUF.loc[dfIndiaSUF['Funding Day'] == '9', 'Funding Day'] = '09'

# %% [markdown]
# #### 'Founding Date' column

# %%
# Changes empty '' values to np.nan
dfIndiaSUF['Founding Date'] = dfIndiaSUF['Founding Date'].replace('',np.nan,regex = True)

# %% [markdown]
# #### 'Industry/Vertical' column

# %%
# Title capitalisation
dfIndiaSUF['Industry/Vertical'] = dfIndiaSUF['Industry/Vertical'].str.title()

# %%
# Renaming and correcting value in 'Industry/Vertical'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ed-Tech', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'E-Learning', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Edtech', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Education', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Online Education Platform', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Edtech Startup', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Education Marketplace', 'Industry/Vertical'] = 'EdTech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Edttech', 'Industry/Vertical'] = 'EdTech'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ai', 'Industry/Vertical'] = 'AI'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ai Startup', 'Industry/Vertical'] = 'AI'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Tech Startup', 'Industry/Vertical'] = 'Technology'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Tech', 'Industry/Vertical'] = 'Technology'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Tech Company', 'Industry/Vertical'] = 'Technology'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Deeptech', 'Industry/Vertical'] = 'Technology'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Deep-Tech', 'Industry/Vertical'] = 'Technology'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food & Beverage', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food And Beverage', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Foodtech', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food And Beverages', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Beverage', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food & Bevarages', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Beverages', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food Industry', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food Tech', 'Industry/Vertical'] = 'Food & Beverages'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Food Production', 'Industry/Vertical'] = 'Food & Beverages'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'It', 'Industry/Vertical'] = 'IT'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Information Technology', 'Industry/Vertical'] = 'IT'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Information Technology & Services', 'Industry/Vertical'] = 'IT'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'It Startup', 'Industry/Vertical'] = 'IT'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Internet', 'Industry/Vertical'] = 'IT'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Techonology', 'Industry/Vertical'] = 'IT'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Saas Startup', 'Industry/Vertical'] = 'Saas'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Automobile', 'Industry/Vertical'] = 'Automotive'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ev Startup', 'Industry/Vertical'] = 'Automotive'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Mobility', 'Industry/Vertical'] = 'Automotive'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ev', 'Industry/Vertical'] = 'Automotive'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'E-Mobility', 'Industry/Vertical'] = 'Automotive'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ecommerce', 'Industry/Vertical'] = 'E-commerce'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'E-Commerce', 'Industry/Vertical'] = 'E-commerce'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Ecommece', 'Industry/Vertical'] = 'E-commerce'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Social Commerce', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Digital Media', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Social E-Commerce', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Online Media', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Social Network', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Online Food Community Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Online Recipe Sharing Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Beauty & Lifestyle Mobile Marketplace', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Mobile Growth Hackingplatform', 'Industry/Vertical'] = 'Platforms & Social Media'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Restaurant Management Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Startup Analytics Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Hiring Analytics Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Fund Raising Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Banking Analytics Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Digital Platform', 'Industry/Vertical'] = 'Platforms & Social Media'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Social Media', 'Industry/Vertical'] = 'Platforms & Social Media'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Health, Wellness & Fitness', 'Industry/Vertical'] = 'Health & Fitness'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Fitness', 'Industry/Vertical'] = 'Health & Fitness'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Health', 'Industry/Vertical'] = 'Health & Fitness'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Health And Wellness', 'Industry/Vertical'] = 'Health & Fitness'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Health & Wellness', 'Industry/Vertical'] = 'Health & Fitness'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Nutrition', 'Industry/Vertical'] = 'Health & Fitness'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Health Care', 'Industry/Vertical'] = 'Hospital & Healthcare'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Heathcare', 'Industry/Vertical'] = 'Hospital & Healthcare'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Heath Care', 'Industry/Vertical'] = 'Hospital & Healthcare'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Fin-Tech', 'Industry/Vertical'] = 'Fintech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Financial Services', 'Industry/Vertical'] = 'Fintech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Finance', 'Industry/Vertical'] = 'Fintech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Finance Company', 'Industry/Vertical'] = 'Fintech'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Apparel & Fashion', 'Industry/Vertical'] = 'Fashion'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Human Resources', 'Industry/Vertical'] = 'HR Tech'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Hr Tech', 'Industry/Vertical'] = 'HR Tech'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Industrial Automation', 'Industry/Vertical'] = 'Automation'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Transport', 'Industry/Vertical'] = 'Transportation'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Logistics', 'Industry/Vertical'] = 'Logistics & Supply Chain'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Fmcg', 'Industry/Vertical'] = 'Consumer Goods'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Consumer Goods', 'Industry/Vertical'] = 'Consumer Goods & Services'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Consumer Services', 'Industry/Vertical'] = 'Consumer Goods & Services'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Consumer Electronics', 'Industry/Vertical'] = 'Consumer Goods & Services'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Hyperlocal Handyman Services', 'Industry/Vertical'] = 'Consumer Goods & Services'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'On-Demand Washing & Dry-Cleaning', 'Industry/Vertical'] = 'Consumer Goods & Services'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'B2B Marketplace', 'Industry/Vertical'] = 'Marketplace'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Professional Custom Creators Marketplace', 'Industry/Vertical'] = 'Marketplace'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'E-Market', 'Industry/Vertical'] = 'Marketplace'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Saas', 'Industry/Vertical'] = 'SaaS'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Computer Software', 'Industry/Vertical'] = 'SaaS'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Software', 'Industry/Vertical'] = 'SaaS'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Saas Platform', 'Industry/Vertical'] = 'SaaS'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Software Company', 'Industry/Vertical'] = 'SaaS'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Private Cloud Networks Saas Platform', 'Industry/Vertical'] = 'SaaS'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Gaming Startup', 'Industry/Vertical'] = 'Gaming'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Insurance', 'Industry/Vertical'] = 'Insuretech'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Solar', 'Industry/Vertical'] = 'Energy'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Solar Products And Services Marketplace', 'Industry/Vertical'] = 'Energy'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Blockchain Startup', 'Industry/Vertical'] = 'Blockchain'

dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'Logitech', 'Industry/Vertical'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Industry/Vertical'] == 'B2B', 'Industry/Vertical'] = 'Other'

dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Education') == True, 'EdTech', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Platform') == True, 'Platforms & Social Media', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Financ') == True, 'Fintech', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Cloud') == True, 'Cloud', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Music') == True, 'Music', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Marketplace') == True, 'Marketplace', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Mobile') == True, 'Mobile App/Service', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Online') == True, 'SaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Dairy') == True, 'Food & Beverages', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Logistics') == True, 'Logistics & Supply Chain', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Logistic') == True, 'Logistics & Supply Chain', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Beverage') == True, 'Food & Beverages', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Food') == True, 'Food & Beverages', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Healthcare') == True, 'Hospital & Healthcare', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Delivery') == True, 'Delivery', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Ai') == True, 'AI', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Estate') == True, 'Real Estate', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Entertainment') == True, 'Entertainment', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Streaming') == True, 'Entertainment', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Marketing') == True, 'Marketing', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Software') == True, 'SaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Fashion') == True, 'Fashion', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Ecommerce') == True, 'E-commerce', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('App') == True, 'Mobile App/Service', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Sports') == True, 'Sports', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Sport') == True, 'Sports', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Paas') == True, 'PaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Automotive') == True, 'Automotive', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Energy') == True, 'Energy', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Iot') == True, 'Iot', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Saas') == True, 'SaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Automobile') == True, 'Automotive', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Supply Chain') == True, 'Logistics & Supply Chain', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Games') == True, 'Games', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Car') == True, 'Automotive', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Tourism') == True, 'Tourism', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Rental') == True, 'Rental', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Hr') == True, 'HR Tech', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Travel') == True, 'Travel & Tourism', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Tourism') == True, 'Travel & Tourism', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Data') == True, 'Data Management', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Waste') == True, 'Waste Management', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Transportation') == True, 'Transportation', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Transport') == True, 'Transportation', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Power') == True, 'Energy', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Consulting') == True, 'Consulting', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Advisory') == True, 'Consulting', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Solar') == True, 'Energy', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Battery') == True, 'Energy', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Fitness') == True, 'Health & Fitness', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Health') == True, 'Health & Fitness', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Service') == True, 'SaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Services') == True, 'SaaS', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('It') == True, 'IT', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Social') == True, 'Platforms & Social Media', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Computer') == True, 'IT', dfIndiaSUF['Industry/Vertical'])
dfIndiaSUF['Industry/Vertical'] = np.where(dfIndiaSUF['Industry/Vertical'].str.contains('Hotel') == True, 'IT', dfIndiaSUF['Industry/Vertical'])

# %%
# Filling empty rows with 'Other'
dfIndiaSUF['Industry/Vertical'] = dfIndiaSUF['Industry/Vertical'].fillna('Other')

# %%
# List (and sum) of all unique values in 'Industry/Vertical' column
dfIndiaSUF['Industry/Vertical'].value_counts()
# Out:
# Consumer Internet    885
# Technology           496
# E-commerce           369
# Fintech              361
# SaaS                 328
#                     ...
# Digital Tech           1
# Co-Living              1
# Retail Tech            1
# Defense Tech           1
# Investment Tech        1
# Name: Industry/Vertical, Length: 302, dtype: int64

# %% [markdown]
# #### 'Sub-Vertical' column

# %%
# Title capitalisation
dfIndiaSUF['Sub-Vertical'] = dfIndiaSUF['Sub-Vertical'].str.title()

# %%
# List (and sum) of all column value
dfIndiaSUF['Sub-Vertical'].value_counts()
# Out:
# Online Lending Platform                                                                 20
# Food Delivery Platform                                                                  10
# Online Pharmacy                                                                         10
# Online Learning Platform                                                                 8
# Online Lending                                                                           5
#                                                                                         ..
# Online Interior Design Platform                                                          1
# Door Step Delivery Platform                                                              1
# Chatbot Creation Tool                                                                    1
# Next Gen Mobility Device Manufacturer                                                    1
# ...

# %% [markdown]
# #### 'City' column

# %%
# Title capitalisation
dfIndiaSUF['City'] = dfIndiaSUF['City'].str.title()

# %%
# List (and sum) of all column value
dfIndiaSUF['City'].value_counts().head(30)
# Out:
# Bangalore        1269
# Mumbai            821
# New Delhi         554
# Gurgaon           284
# Gurugram          251
# Pune              175
# Chennai           159
# Hyderabad         143
# Noida             135
# Bengaluru         131
# Delhi              83
# Ahmedabad          51
# Jaipur             44
# Kolkata            30
# Indore             22
# Chandigarh         18
# Haryana            14
# Goa                14
# Singapore          12
# Thane              12
# Vadodara           11
# Kochi               8
# Coimbatore          8
# Gujarat             8
# California          6
# Ahmadabad           6
# Jodhpur             5
# Kanpur              5
# San Francisco       5
# Faridabad           4
# Name: City, dtype: int64

# %%
# Correcting or deleting 'city' column

# 1/4
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Udaipur', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Ahemadabad', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Ahemdabad', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Ambernath', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Andheri', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bangalore/ Bangkok', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bangalore/ Bangkok', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bangalore/ Palo Alto', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bangalore/ Sfo', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bangalore/ USA', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bankok', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Beijing', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bengaluru And Gurugram', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Berlin', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bhubneswar', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bihar', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Boston', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Burnsville', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'California', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Chembur', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Chennai/ Singapore', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Computer Games', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Dalls / Hyderabad', 'City'] = 'Greater Hyderabad '
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Dehli & Cambridge', 'City'] = 'New Dehli'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Dhingsara,Haryana', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Faridabad,Haryana', 'City'] = 'Faridabad'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Food & Beverages', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Frisco,Texas,United States', 'City'] = np.nan

# 2/4
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Goa/Hylderabad', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Gujarat', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Gurgaon / Sfo', 'City'] = 'Gurgaon'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Gurugram', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Haryana', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Hyderabad/Usa', 'City'] = 'Greater Hyderabad '
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Hyderabad', 'City'] = 'Greater Hyderabad '
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'India', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'India/Singapore', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Inda / Us', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Inda/Us', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Jaipur,Rajastan', 'City'] = 'Jaipur'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Jiaxing,Zhejiang,China', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Karnataka', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Kerala', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Kolkatta', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Kormangala', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'London', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Menlo Park', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Missourie', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mountain View,Ca', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mumbai/Bengaluru', 'City'] = 'Greater Mumbai'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mumbai / Global', 'City'] = 'Greater Mumbai'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mumbai / Ny', 'City'] = 'Greater Mumbai'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mumbai / Uk', 'City'] = 'Greater Mumbai'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Nairobi / Uk', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Nairobi', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New Delhi / California', 'City'] = 'New Delhi'

# 3/4
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New Delhi/ Houston', 'City'] = 'New Delhi'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New Delhi / Us', 'City'] = 'New Delhi'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New York', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New York,Bengaluru', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'New York,United States', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Noida / Singapore', 'City'] = 'Noida'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Null', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'nw Delhi', 'City'] = 'New Delhi'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Odisha', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Orissia', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Palo Alto', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == '', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Pune / Dubai', 'City'] = 'Pune'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Pune/Seattle', 'City'] = 'Pune'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Pune / US', 'City'] = 'Pune'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Rajastan', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Riyadh', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Samsitpur', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'San Franciscao', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'San Francisco', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Santa Monica', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Santra', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Seattle', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Seattle / Bangalore', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Seoul', 'City'] = np.nan

# 4/4
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'sfo', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'sfo / Bangalore', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Singapore', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Small Towns,Andhra Pradesh', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Tangerang,Jawa Barat,Indonesia', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Taramani', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Telangana', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Telugana', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'The Nilgiris', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Tirunelveli,Tamilnadu', 'City'] = 'Tirunelveli'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Tulangan', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Us', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Usa', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Usa/India', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Us/India', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Uttar Pradesh', 'City'] = np.nan
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'West Bengal', 'City'] = np.nan

# Rest
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Mumbai', 'City'] = 'Greater Mumbai'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Bengaluru', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Pune / Us', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'India/Us', 'City'] = 'Bangalore'
dfIndiaSUF.loc[dfIndiaSUF['City'] == 'Faridabad, Haryana', 'City'] = 'Faridabad'

# %% [markdown]
# #### 'Investor(s)' column

# %%
# Title capitalisation
dfIndiaSUF['Investor(s)'] = dfIndiaSUF['Investor(s)'].str.title()

# %%
# List (and sum) of all column value
dfIndiaSUF['Investor(s)'].value_counts()
# Out:
# Undisclosed Investors                             78
# Venture Catalysts                                 32
# Indian Angel Network                              28
# Inflection Point Ventures                         27
# Ratan Tata                                        25
#                                                   ..
# Rebright Partners                                  1
# Currae Healthtech Fund, Unicorn India Ventures     1
# Vertex Ventures, Cisco Ventures, Idg Ventures      1
# Rohit Ma                                           1
# Ocean View Investment, Qed Fund                    1
# Name: Investor(s), Length: 3550, dtype: int64

# %% [markdown]
# #### 'Investment Type' column

# %%
# Title capitalisation
dfIndiaSUF['Investment Type'] = dfIndiaSUF['Investment Type'].str.title()

# %%
# List (and sum) of all column value
dfIndiaSUF['Investment Type'].value_counts()
# Out:
# Private Equity     1229
# Seed Funding       1221
# Seed                280
# Series A            209
# Pre-Series A        182
#                    ...
# Funding Round         1
# Series C, D           1
# Pre Series C          1
# Seed Investment       1
# Series I              1
# Name: Investment Type, Length: 82, dtype: int64

# %%
# Renaming value 
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Seed Round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Early Seed', 'Investment Type'] = 'Seed'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Funding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Funding Round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Investment', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed+', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seedfunding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed/Angel', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed A', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed Round & Series A', 'Investment Type'] = 'Seed'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Private Equity Round', 'Investment Type'] = 'Private Equity'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Bridge Funding', 'Investment Type'] = 'Bridge'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Bridge Round', 'Investment Type'] = 'Bridge'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'pre-series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-series A1', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Series A1', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre- Series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Series-A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Series A1', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Series A', 'Investment Type'] = 'Series A'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Series B', 'Investment Type'] = 'Series B'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Series C', 'Investment Type'] = 'Series C'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Series C', 'Investment Type'] = 'Series C'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series C, D', 'Investment Type'] = 'Series C'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seies A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series A+', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series A-1', 'Investment Type'] = 'Series A'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series B (Extension)', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series B3', 'Investment Type'] = 'Series B'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series D1', 'Investment Type'] = 'Series D'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series E2', 'Investment Type'] = 'Series E'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series F1', 'Investment Type'] = 'Series F'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series F2', 'Investment Type'] = 'Series F'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Equity Based Funding', 'Investment Type'] = 'Equity'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Private Equity', 'Investment Type'] = 'Equity'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Debt Funding', 'Investment Type'] = 'Debt'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Debt-Funding', 'Investment Type'] = 'Debt'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Debt And Preference Capital', 'Investment Type'] = 'Debt'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Strategic Funding', 'Investment Type'] = 'Strategic Investmentment'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Venture Round', 'Investment Type'] = 'Venture'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Single Venture', 'Investment Type'] = 'Venture'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Angel Round', 'Investment Type'] = 'Angel'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Angel Funding', 'Investment Type'] = 'Angel'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed/Angel Funding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed/ Angel Funding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed / Angel Funding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed / Angle Funding', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Angel / Seed Funding', 'Investment Type'] = 'Seed'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Early seed', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Seed', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre seed round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-seed Round', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre Seed Round', 'Investment Type'] = 'Seed'

# %%
# Renaming values
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Series', 'Investment Type'] = 'Seed'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-seed', 'Investment Type'] = 'Seed'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Pre-Series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE pre-Series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Pre-Series A bridge round', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Pre-Series A Bridge', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Part of Series A raised inJune 2015', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Pre Series-A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE pre-series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE pre series A', 'Investment Type'] = 'Series A'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series I', 'Investment Type'] = 'Series A'
                                        
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series B', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Pre-Series B', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pre-Series B', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series B (includes Debt financing)', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series B (More Here)', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Part of $12M Series B funding', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE part of $40M Series B round', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series B Interim Funding', 'Investment Type'] = 'Series B'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Bridge Round Pre-Series B', 'Investment Type'] = 'Series B'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series C', 'Investment Type'] = 'Series C'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series C(More here)', 'Investment Type'] = 'Series C'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series D', 'Investment Type'] = 'Series D'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series D( In Feb it was announced they raised 26M, but it is 36M, so added here)', 'Investment Type'] = 'Series D'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series E', 'Investment Type'] = 'Series E'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series E (Updated from 315M to 400M after Press Release)', 'Investment Type'] = 'Series E'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series F (More Details Here)', 'Investment Type'] = 'Series F'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series G (Checkprev funding details her)', 'Investment Type'] = 'Series G'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Series G (Checkprev funding details here)', 'Investment Type'] = 'Series G'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Late Stage', 'Investment Type'] = 'Late Stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Late Stage (Alibaba @ 40% equity)', 'Investment Type'] = 'Late Stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE late Stage (part of $500M funding rnd)', 'Investment Type'] = 'Late Stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Late Stage, 10th RoundMore here', 'Investment Type'] = 'Late Stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Late Stage Round 7th (More details)', 'Investment Type'] = 'Late Stage'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Bridge funding', 'Investment Type'] = 'Bridge'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Bridge round', 'Investment Type'] = 'Bridge'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Bridge Round', 'Investment Type'] = 'Bridge'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE More details', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Strategic Funding', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Additional investment from parent company', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Additional Funding', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Pe', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Private', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Term Loan', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Mezzanine', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Edge', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Funding Round', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Mid Series', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Inhouse Funding', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Personal Investment ', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Majority Stake', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Maiden Round', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Promoter Commitment', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Corporate Round', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Crowd Funding', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE 3rd Round', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Strategic Investment (Majority Stake)', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Follow on Funding', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Strategic Funding, Minority stake', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Minority stake, Strategic', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE 1% stake', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Personal Investment', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Govt backed VC Fund', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Strategic Investment (25% stake)', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Incremental Capital', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE No confirmation', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'PE Strategic Investment', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Venture - Series Unknown', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Privateequity', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Venture', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Equity', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Angel', 'Investment Type'] = 'Other'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Bridge', 'Investment Type'] = 'Other'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series D', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series E', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series F', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series G', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series H', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Series J', 'Investment Type'] = 'Series D to late stage'
dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Late Stage', 'Investment Type'] = 'Series D to late stage'

dfIndiaSUF.loc[dfIndiaSUF['Investment Type'] == 'Seed', 'Investment Type'] = 'Early stage'

# %%
# Locating incorrect columns
dfIndiaSUF[dfIndiaSUF['Investment Type'] == "$300000"]
# Out:
#    Startup Name                                         Founder(s)  \
# 79  Little Leap  Holistic Development Programs For Children In ...
# 92        Bhyve                                  Backed By 100X.Vc
#
#     Funding Date Funding Month Funding Day Founding Date Industry/Vertical  \
# 79          2021            07          01          2020            EdTech
# 92          2021            07          01          2020           HR Tech
#
#                                          Sub-Vertical            City  \
# 79                Soft Skills That Make Smart Leaders       New Delhi
# 92  A Future Of Work Platform For Diffusing Employ...  Greater Mumbai
#
#                         Investor(s)         Investment Amount (USD)  \
# 79                     Vishal Gupta                    ah! Ventures
# 92  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture
#
#    Investment Type Remarks
# 79         $300000     NaN
# 92         $300000     NaN

# %%
# Locating incorrect columns
dfIndiaSUF[dfIndiaSUF['Investment Type'] == "$1200000"]
# Out:
#    Startup Name Founder(s)  Funding Date Funding Month Funding Day  \
# 11      Fanplay     Yc W21          2021            08          01
# 24      Fanplay     Yc W21          2021            08          01
#
#    Founding Date Industry/Vertical  \
# 11        2020.0             Games
# 24        2020.0             Games
#
#                                          Sub-Vertical City  \
# 11  A Real Money Game App Specializing In Trivia G...  NaN
# 24  A Real Money Game App Specializing In Trivia G...  NaN
#
#                     Investor(s) Investment Amount (USD) Investment Type  \
# 11  Pritesh Kumar, Bharat Gupta                Upsparks        $1200000
# 24  Pritesh Kumar, Bharat Gupta                Upsparks        $1200000
#
#    Remarks
# 11     NaN
# 24     NaN

# %%
# Locating incorrect columns
dfIndiaSUF[dfIndiaSUF['Investment Type'] == "$6000000"]
# Out:
#     Startup Name                               Founder(s)  Funding Date  \
# 82  Myre Capital  Own Rent Yielding Commercial Properties          2021
#
#    Funding Month Funding Day Founding Date Industry/Vertical  \
# 82            06          01          2020       Real Estate
#
#                            Sub-Vertical            City  Investor(s)  \
# 82  Democratising Real Estate Ownership  Greater Mumbai  Aryaman Vir
#
#    Investment Amount (USD) Investment Type Remarks
# 82                     NaN        $6000000     NaN

# %%
# Locating incorrect columns
dfIndiaSUF[dfIndiaSUF['Investment Type'] == "$1000000"]
# Out:
#         Startup Name Founder(s)  Funding Date Funding Month Funding Day  \
# 85  Saarthi Pedagogy   Pedagogy          2021            06          01
#
#    Founding Date Industry/Vertical  \
# 85          2015            EdTech
#
#                                          Sub-Vertical       City  \
# 85  India'S Fastest Growing Pedagogy Company, Serv...  Ahmadabad
#
#        Investor(s)          Investment Amount (USD) Investment Type Remarks
# 85  Sushil Agarwal  JITO Angel Network, LetsVenture        $1000000     NaN

# %%
# Inserting data to correct column
dfIndiaSUF.at[79, 'Investment Amount (USD)'] = dfIndiaSUF.at[79, 'Investment Type']
dfIndiaSUF.at[92, 'Investment Amount (USD)'] = dfIndiaSUF.at[92, 'Investment Type']
dfIndiaSUF.at[11, 'Investment Amount (USD)'] = dfIndiaSUF.at[11, 'Investment Type']
dfIndiaSUF.at[24, 'Investment Amount (USD)'] = dfIndiaSUF.at[24, 'Investment Type']
dfIndiaSUF.at[82, 'Investment Amount (USD)'] = dfIndiaSUF.at[82, 'Investment Type']
dfIndiaSUF.at[85, 'Investment Amount (USD)'] = dfIndiaSUF.at[85, 'Investment Type']

# Deleting incorrect data in column
dfIndiaSUF.at[79, 'Investment Type'] = np.nan
dfIndiaSUF.at[92, 'Investment Type'] = np.nan
dfIndiaSUF.at[11, 'Investment Type'] = np.nan
dfIndiaSUF.at[24, 'Investment Type'] = np.nan
dfIndiaSUF.at[82, 'Investment Type'] = np.nan
dfIndiaSUF.at[85, 'Investment Type'] = np.nan

# %%
# Locating all rows with Private Equity in 'Investment Type'
dfIndiaSUF[dfIndiaSUF['Investment Type'] == 'Private Equity'].head(50)
# Out:
# Empty DataFrame
# Columns: [Startup Name, Founder(s), Funding Date, Funding Month, Funding Day, Founding Date, Industry/Vertical, Sub-Vertical, City, Investor(s), Investment Amount (USD), Investment Type, Remarks]
# Index: []

# %%
# If 'Investment Type' is Private Equity, then it replaces the value with 'PE ' + 'Remarks' column with relevant data
dfIndiaSUF['Investment Type'] = np.where(dfIndiaSUF['Investment Type'] == 'Private Equity', 'PE ' + dfIndiaSUF['Remarks'], dfIndiaSUF['Investment Type'])

# %%
# Locating all rows with Private Equity in 'Investment Type'
dfIndiaSUF[dfIndiaSUF['Investment Type'] == 'Debt'].head(50)
# Out:
#                                           Startup Name  \
# 20                                         Lendingkart
# 42                                         Fieldassist
# 13                                        Early Salary
# 16                                         Aye Finance
# 41                                           Yatra.Com
# 47                                                 Fr8
# 10                                             Eshakti
# 15                                            Furlenco
# 30                                        Cash Suvidha
# 4                                          Lendingkart
# 35                                             Curefit
# 16                                             Cashify
# 10                                              Ad2Pro
# 13                                            Magicpin
# 19                                           Fingerlix
# 14                                          Ayefinance
# ...

# %% [markdown]
# #### 'Investment Amount (USD)' column

# %%
dfIndiaSUF[dfIndiaSUF['Investment Amount (USD)'].isnull()]
# Out:
#            Startup Name                                         Founder(s)  \
# 7              Loginext                                                NaN
# 15      Purple Squirrel                                                NaN
# 17            Immi Life                                                NaN
# 31             Doormint                                                NaN
# 32                Vyomo                                                NaN
# ..                  ...                                                ...
# 38             Sochcast            Vinners, Raj Nayak, Amritaanshu Agrawal
# 85             Tinkerly  O.P. Godara, Vivek Pathak, Kapil Arya, Sharad ...
# 11              Zoomcar                                         Greg Moran
# 88  Karkinos Healthcare                                                NaN
# 92              Zorgers             Varun Gupta, Anil Kumar, Abhinav Gupta
#
#     Funding Date Funding Month Funding Day Founding Date  \
# ...

# %%
# Removes all non digit values from column
dfIndiaSUF['Investment Amount (USD)'] = dfIndiaSUF['Investment Amount (USD)'].str.replace(r'[^0-9]+', '')

# %%
# Changes empty values to np.nan
dfIndiaSUF.loc[dfIndiaSUF['Investment Amount (USD)'] == '', 'Investment Amount (USD)'] = np.nan

# %%
# Changes np.nan values to 0
dfIndiaSUF['Investment Amount (USD)'] = dfIndiaSUF['Investment Amount (USD)'].fillna(0)

# %%
# Changes all values to string data type
dfIndiaSUF['Investment Amount (USD)'] = dfIndiaSUF['Investment Amount (USD)'].astype(str)

# %%
# Showing rows with more than 10 characters in 'Investment Amount (USD)'
dfIndiaSUF[dfIndiaSUF['Investment Amount (USD)'].str.len() > 10]
# Out:
#        Startup Name            Founder(s)  Funding Date Funding Month  \
# 4      True Balance  Charlie, Jay, Martin          2020            08
# 73  Alteria Capital          Vinod Murali          2021            04
#
#    Funding Day Founding Date Industry/Vertical  \
# 4           01          2014           Fintech
# 73          01          2018           Fintech
#
#                                          Sub-Vertical            City  \
# 4   Earn Money By Meeting Financial Needs Of Your ...             NaN
# 73           Alteria Capital Is A Venture Debt Firm .  Greater Mumbai
#
#     Investor(s) Investment Amount (USD) Investment Type Remarks
# 4   Balancehero          88700023000000        Series C     NaN
# 73          NaN            150000000000            Debt     NaN

# %%
# Correcting and deleting incorrect values 
dfIndiaSUF.loc[dfIndiaSUF['Investment Amount (USD)'] == '88700023000000', 'Investment Amount (USD)'] = "23000000"
dfIndiaSUF.loc[dfIndiaSUF['Investment Amount (USD)'] == '150000000000', 'Investment Amount (USD)'] = "0"

# %%
# Changes all values to integer data type
dfIndiaSUF['Investment Amount (USD)'] = dfIndiaSUF['Investment Amount (USD)'].astype(int)

# %% [markdown]
# #### 'Task' Column

# %% [markdown]
# #### Duplicates and final data cleaning

# %%
# Changing empty values to NaN
dfIndiaSUF = dfIndiaSUF.replace('',np.nan,regex = True)

# %%
# Sum of duplicate entire rows
dfIndiaSUF.duplicated().value_counts()
# Out:
# False    4697
# True       19
# dtype: int64

# %%
# Print of row duplicates, sorted by 'Startup Name'
dfIndiaSUF[dfIndiaSUF.duplicated() == True].sort_values(by='Startup Name', ascending=True)
# Out:
#            Startup Name                                     Founder(s)  \
# 30       Advantage Club             Sourabh Deorah, Smiti Bhatt Deorah
# 40        Asqi Advisors                                  Swapnil Pawar
# 22             Bewakoof                               Prabhkiran Singh
# 137            Byju’s                                Byju Raveendran
# 20            Curefoods                                   Ankit Nagori
# 39              Enmovil     Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 42      Evenflow Brands                  Utsav Agarwal, Pulkit Chhabra
# 36          Fananywhere                    Varun Chaudhary, Amit Kumar
# 24              Fanplay                                         Yc W21
# 44   Fullife Healthcare             Morgan Stanley Private Equity Asia
# 41   Insurance Samadhan                     Deepak Bhuvenshwari Uniyal
# 54            Krimanshi                                   Nikhil Bohra
# ...

# %%
# Deleting duplicated rows
dfIndiaSUF = dfIndiaSUF.drop_duplicates()

# %%
# Sorting Entire data set by 'Funding Date', and if possible by 'Funding Date' and 'Funding Date', in ascending order
dfIndiaSUF = dfIndiaSUF.sort_values(by=['Funding Date', 'Funding Month', 'Funding Day'], ascending=[True, True, True])

# %%
# Resetting the index 
dfIndiaSUF = dfIndiaSUF.reset_index()

# %%
# Deleting the first column
dfIndiaSUF = dfIndiaSUF.iloc[:,1:]

# %%
# Changes date type to string
dfIndiaSUF['Funding Date'] = dfIndiaSUF['Funding Date'].astype(str)

# %%
#### Fills all values in 'Funding Month' and 'Funding Day' to 01
dfIndiaSUF['Funding Day'] = dfIndiaSUF['Funding Day'].fillna('01')
dfIndiaSUF['Funding Month'] = dfIndiaSUF['Funding Month'].fillna('01')

# %%
# Renaming column
dfIndiaSUF = dfIndiaSUF.rename(columns={"Funding Date": "Funding Year"})

# %%
# Creating date column for Tableau
dfIndiaSUF.insert(2, 'Funding Date', dfIndiaSUF['Funding Day'] + "/" + dfIndiaSUF['Funding Month'] + "/" + dfIndiaSUF['Funding Year'])

# %%
# Moving 'Funding Date' column, by assigning it, deleting it, and then adding it again
dfIndiaSUF_FundingDate = dfIndiaSUF.pop('Funding Date')
dfIndiaSUF.insert(7, 'Funding Date', dfIndiaSUF_FundingDate)

# %%
# Exporting 'Industry/Vertical' column for data cleanup of last values
# Will override edited file, therefore only done first time
#dfIndiaSUF['Industry/Vertical'].to_excel('Industry-Vertical.xlsx')

# Importing cleaned file again
dfIndiaSUFIV = pd.read_csv('Industry-Vertical.csv', skipinitialspace = True, sep=";")

# %%
# Updating values in main data set
dfIndiaSUF['Industry/Vertical'] = dfIndiaSUFIV['Industry/Vertical']

# %%
# Changes 'Debt' values in 'Investment Type' column based on assumptions
dfIndiaSUF['Investment Type'] = np.where(((dfIndiaSUF['Investment Type'] == 'Debt') & (dfIndiaSUF['Investment Amount (USD)'] < 10000000)), 'Early Stage', dfIndiaSUF['Investment Type'])
dfIndiaSUF['Investment Type'] = np.where(((dfIndiaSUF['Investment Type'] == 'Debt') & (dfIndiaSUF['Investment Amount (USD)'] < 20000000)), 'Series A', dfIndiaSUF['Investment Type'])
dfIndiaSUF['Investment Type'] = np.where(((dfIndiaSUF['Investment Type'] == 'Debt') & (dfIndiaSUF['Investment Amount (USD)'] < 40000000)), 'Series B', dfIndiaSUF['Investment Type'])
dfIndiaSUF['Investment Type'] = np.where(((dfIndiaSUF['Investment Type'] == 'Debt') & (dfIndiaSUF['Investment Amount (USD)'] < 70000000)), 'Series C', dfIndiaSUF['Investment Type'])
dfIndiaSUF['Investment Type'] = np.where(((dfIndiaSUF['Investment Type'] == 'Debt') & (dfIndiaSUF['Investment Amount (USD)'] >= 70000000)), 'Series D to late stage', dfIndiaSUF['Investment Type'])

# %%
# Filling all np.nan values to 'Other'
dfIndiaSUF['Investment Type'] = dfIndiaSUF['Investment Type'].fillna('Other')

# %%
# Chaning all 'Other' values to np.nan, if 'Investment Amount (USD)' is 0
dfIndiaSUF['Investment Type'] = np.where((dfIndiaSUF['Investment Amount (USD)'] == 0), np.nan, dfIndiaSUF['Investment Type'])

# %% [markdown]
# ### Updated data set

# %%
dfIndiaSUF.head(2)
# Out:
#    Startup Name Founder(s) Funding Year Funding Month Funding Day  \
# 0      Lenskart        NaN         2015            01          02
# 1  Violetstreet        NaN         2015            01          02
#
#   Founding Date Industry/Vertical Funding Date Sub-Vertical City  \
# 0           NaN             Other   02/01/2015          NaN  NaN
# 1           NaN             Other   02/01/2015          NaN  NaN
#
#                                          Investor(s)  Investment Amount (USD)  \
# 0               Tpg Growth, Tr Capital, Idg Ventures                  2150000
# 1  Venkat Vallabhneni, Sudhakar Reddy, Srinivasa ...                   315000
#
#   Investment Type Remarks
# 0           Other     NaN
# 1     Early stage     NaN

# %%
# Exporting dataframe data set as csv file
dfIndiaSUF.to_csv('Indian_Start_Up_Data_v1.csv')

# %%
# Exporting dataframe data set as excel file
dfIndiaSUF.to_excel('Indian_Start_Up_Data_v1.xlsx')
